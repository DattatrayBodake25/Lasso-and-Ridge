# %%
#Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
#importing Data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/aishwaryamate/Datasets/main/cars.csv')

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# ...

# %%
df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.describe()
# Out:
#         symboling       width      height  engine-size    city-mpg  \
# count  205.000000  205.000000  205.000000   205.000000  205.000000
# mean     0.834146   65.907805   53.724878   126.907317   25.219512
# std      1.245307    2.145204    2.443522    41.642693    6.542142
# min     -2.000000   60.300000   47.800000    61.000000   13.000000
# 25%      0.000000   64.100000   52.000000    97.000000   19.000000
# 50%      1.000000   65.500000   54.100000   120.000000   24.000000
# 75%      2.000000   66.900000   55.500000   141.000000   30.000000
# max      3.000000   72.300000   59.800000   326.000000   49.000000
#
#        highway-mpg         price
# count   205.000000    205.000000
# mean     30.751220  13227.478049
# std       6.886443   7902.651615
# min      16.000000   5118.000000
# 25%      25.000000   7788.000000
# 50%      30.000000  10345.000000
# 75%      34.000000  16500.000000
# max      54.000000  45400.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# body-style            object
# drive-wheels          object
# engine-location       object
# width                float64
# height               float64
# engine-type           object
# engine-size            int64
# horsepower            object
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
df.replace('?',np.nan,inplace=True)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3               NaN  alfa-romero       gas  convertible
# 1          3               NaN  alfa-romero       gas  convertible
# 2          1               NaN  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
df.isna().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# body-style            0
# drive-wheels          0
# engine-location       0
# width                 0
# height                0
# engine-type           0
# engine-size           0
# horsepower            2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
#cheking null values and replace it with mean

# %%
# pd.options.display.max_rows = 205

# %%
# df['normalized-losses'].unique()

# %%
# df['normalized-losses'] = pd.to_numeric(df['normalized-losses'], errors='coerce')

# %%
# df['normalized-losses'].dtypes

# %%
# df['normalized-losses'].fillna(df['normalized-losses'].mean,inplace=True)

# %%
# df['normalized-losses']

# %%
# df['horsepower'].fillna(df['horsepower'].mean(),inplace=True)

# %%
# df['horsepower'] = df['horsepower'].astype(int)

# %%
# df.isna().sum()

# %%
# df.head()

# %% [markdown]
# #                                           OR
# filling null values with mean using simple imputer

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer()

# %%
df.iloc[:,[1,11]]
# Out:
#     normalized-losses horsepower
# 0                 NaN        111
# 1                 NaN        111
# 2                 NaN        154
# 3                 164        102
# 4                 164        115
# ..                ...        ...
# 200                95        114
# 201                95        160
# 202                95        134
# 203                95        106
# 204                95        114
#
# [205 rows x 2 columns]

# %%
df.iloc[:,[1,11]] = si.fit_transform(df.iloc[:,[1,11]])

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type   body-style  \
# 0          3              122.0  alfa-romero       gas  convertible
# 1          3              122.0  alfa-romero       gas  convertible
# 2          1              122.0  alfa-romero       gas    hatchback
# 3          2              164.0         audi       gas        sedan
# 4          2              164.0         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#    horsepower  city-mpg  highway-mpg  price
# 0       111.0        21           27  13495
# ...

# %%
df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# body-style            object
# drive-wheels          object
# engine-location       object
# width                float64
# height               float64
# engine-type           object
# engine-size            int64
# horsepower           float64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %% [markdown]
# # Encoding

# %% [raw]
# #conversion the categorical data into numerical format using encoding
# Encoding -1)OHE
#           2)Dummy Variable
#
# In Sklearn 1)Ordinal Encoder - for independent column
#            2)Label Encoder - for Target Column

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type   body-style  \
# 0          3              122.0  alfa-romero       gas  convertible
# 1          3              122.0  alfa-romero       gas  convertible
# 2          1              122.0  alfa-romero       gas    hatchback
# 3          2              164.0         audi       gas        sedan
# 4          2              164.0         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#    horsepower  city-mpg  highway-mpg  price
# 0       111.0        21           27  13495
# ...

# %%
 from sklearn.preprocessing import OrdinalEncoder   #for independent features

# %%
oe = OrdinalEncoder()

# %%
#Selecting only categorical columns 

cat_cols = df.select_dtypes(object).columns

# %%
cat_cols
# Out:
# Index(['make', 'fuel-type', 'body-style', 'drive-wheels', 'engine-location',
#        'engine-type'],
#       dtype='object')

# %%
df[cat_cols] = oe.fit_transform(df[cat_cols])

# %%
df
# Out:
#      symboling  normalized-losses  make  fuel-type  body-style  drive-wheels  \
# 0            3              122.0   0.0        1.0         0.0           2.0
# 1            3              122.0   0.0        1.0         0.0           2.0
# 2            1              122.0   0.0        1.0         2.0           2.0
# 3            2              164.0   1.0        1.0         3.0           1.0
# 4            2              164.0   1.0        1.0         3.0           0.0
# ..         ...                ...   ...        ...         ...           ...
# 200         -1               95.0  21.0        1.0         3.0           2.0
# 201         -1               95.0  21.0        1.0         3.0           2.0
# 202         -1               95.0  21.0        1.0         3.0           2.0
# 203         -1               95.0  21.0        0.0         3.0           2.0
# 204         -1               95.0  21.0        1.0         3.0           2.0
#
# ...

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso,Ridge

# %%
x = df.iloc[:,:-1]
y = df['price']

# %%
x.head()
# Out:
#    symboling  normalized-losses  make  fuel-type  body-style  drive-wheels  \
# 0          3              122.0   0.0        1.0         0.0           2.0
# 1          3              122.0   0.0        1.0         0.0           2.0
# 2          1              122.0   0.0        1.0         2.0           2.0
# 3          2              164.0   1.0        1.0         3.0           1.0
# 4          2              164.0   1.0        1.0         3.0           0.0
#
#    engine-location  width  height  engine-type  engine-size  horsepower  \
# 0              0.0   64.1    48.8          0.0          130       111.0
# 1              0.0   64.1    48.8          0.0          130       111.0
# 2              0.0   65.5    52.4          5.0          152       154.0
# 3              0.0   66.2    54.3          3.0          109       102.0
# 4              0.0   66.4    54.3          3.0          136       115.0
#
#    city-mpg  highway-mpg
# 0        21           27
# 1        21           27
# ...

# %%
y.head()
# Out:
# 0    13495
# 1    16500
# 2    16500
# 3    13950
# 4    17450
# Name: price, dtype: int64

# %%
sc = StandardScaler()
x = sc.fit_transform(x)

# %%
#splitting data
xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size=0.25,random_state=1)

# %% [markdown]
# # Model Building

# %% [markdown]
# # 1) Linear Regression

# %%
lr = LinearRegression()
lr.fit(xtrain,ytrain)
ypred = lr.predict(xtest)
print('Training Accuracy: ',lr.score(xtrain,ytrain))
print('Testing Accuracy: ',lr.score(xtest,ytest))
# Out:
# Training Accuracy:  0.9111012990636045
# Testing Accuracy:  0.7477791732054961

# %%
lr.coef_
# Out:
# array([ 1521.35944963,  -202.42206103,  -820.64830407,  -772.29610006,
#          225.76072099,  1336.38502992,  2417.50112889,  2242.39066102,
#          417.79031367,   187.95531802,  3569.08350637, -1293.65007415,
#         3116.79052833, -4808.71281275])

# %% [markdown]
#  - Training accuracy is high - low bias
#  - Testing accuarcy is low - high variance
#
# **Overfitting**

# %% [markdown]
# # 1) Ridge Regression

# %%
rg = Ridge()
rg.fit(xtrain,ytrain)
rgpred =rg.predict(xtest)
print('Training Accuracy: ',rg.score(xtrain,ytrain))
print('Testing Accuracy: ',rg.score(xtest,ytest))
# Out:
# Training Accuracy:  0.9085296066949305
# Testing Accuracy:  0.7629948761700049

# %%
rg.coef_
# Out:
# array([ 1261.95732196,  -101.36340862,  -831.87912035,  -848.60502032,
#           44.71377696,  1222.43619082,  2252.73052447,  2082.87450867,
#          566.86844414,   323.4114035 ,  3494.20492173, -1127.14820336,
#         1553.98079567, -3307.87263687])

# %% [markdown]
# # 2) Lasso Regression

# %%
ls = Lasso()
ls.fit(xtrain,ytrain)
ls_pred = ls.predict(xtest)
print('Training Accuracy: ',ls.score(xtrain,ytrain))
print('Testing Accuracy: ',ls.score(xtest,ytest))
# Out:
# Training Accuracy:  0.9110997188729013
# Testing Accuracy:  0.7482832357659347

# %%
ls.coef_
# Out:
# array([ 1510.33250066,  -196.3540313 ,  -819.36378224,  -773.30855668,
#          218.29066096,  1330.69996197,  2413.97799933,  2238.76587814,
#          420.25638565,   189.64128126,  3568.53197831, -1290.77071754,
#         3081.46020368, -4776.22956154])

# %% [markdown]
# # Selecting of Alpha

# %%
for i in range(50,200):
    rg = Ridge(alpha=i)
    rg.fit(xtrain,ytrain)
    y = rg.predict(xtest)
    
    print(f"{i} {rg.score(xtrain,ytrain)} {rg.score(xtest,ytest)}")
# Out:
# 50 0.8224552378404965 0.7367531268154052
# 51 0.8210531656962479 0.7356459262650613
# 52 0.8196555382618008 0.7345374273796894
# 53 0.8182622910597762 0.7334277888343318
# 54 0.8168733633668617 0.7323171610640433
# 55 0.8154886978896838 0.7312056867850245
# 56 0.8141082404764177 0.7300935014759835
# 57 0.8127319398595807 0.7289807338233737
# 58 0.8113597474260851 0.7278675061337464
# 59 0.8099916170111681 0.7267539347161034
# 60 0.8086275047132745 0.7256401302368272
# 61 0.8072673687273615 0.7245261980495046
# 62 0.805911169194432 0.7234122385017228
# 63 0.8045588680653895 0.7222983472207138
# 64 0.8032104289775616 0.7211846153795438
# 65 0.801865817142444 0.7200711299453826
# 66 0.80052499924341 0.7189579739112488
# 67 0.7991879433422825 0.7178452265124996
# 68 0.7978546187938058 0.7167329634292199
# 69 0.7965249961671758 0.715621256975568
# 70 0.7951990471738829 0.7145101762770409
# 71 0.793876744601221 0.7133997874365448
# 72 0.7925580622508851 0.7122901536900769
# ...

# %%
for i in range(3000,4000):
    ls = Lasso(alpha=i)
    ls.fit(xtrain,ytrain)
    y = ls.predict(xtest)
    
    print(f"{i} {ls.score(xtrain,ytrain)} {ls.score(xtest,ytest)}")
# Out:
# 3000 0.6101862394283721 0.5947996422801742
# 3001 0.6100315843340992 0.5946826144790291
# 3002 0.6098768777023378 0.5945655436869111
# 3003 0.6097221195330884 0.5944484299038209
# 3004 0.6095673098263503 0.5943312731297576
# 3005 0.6094124485821237 0.594214073364722
# 3006 0.6092575358004093 0.5940968306087139
# 3007 0.6091025714812064 0.5939795448617331
# 3008 0.608947555624515 0.5938622161237798
# 3009 0.6087924882303353 0.5937448443948539
# 3010 0.6086373692986671 0.5936274296749553
# 3011 0.6084821988295106 0.5935099719640843
# 3012 0.608326976822866 0.5933924712622406
# 3013 0.6081717032787328 0.5932749275694245
# 3014 0.6080163781971115 0.5931573408856357
# 3015 0.6078610015780015 0.5930397112108743
# 3016 0.6077055734214033 0.5929220385451401
# 3017 0.6075500937273168 0.5928043228884337
# 3018 0.6073945624957421 0.5926865642407546
# 3019 0.6072389797266786 0.5925687626021028
# 3020 0.607083345420127 0.5924509179724783
# 3021 0.6069276595760873 0.5923330303518815
# ...
